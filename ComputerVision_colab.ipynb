# %%
import cv2
from google.colab.patches import cv2_imshow

img1 = cv2.imread('fiber.jpg')

cv2_imshow(img1)

cv2.waitKey()

cv2.destroyAllWindows
# Out:
# <PIL.Image.Image image mode=RGB size=600x422>
# <function destroyAllWindows>

# %%
img2 = cv2.imread('fiber.jpg', cv2.IMREAD_GRAYSCALE)

cv2_imshow(img2)

cv2.waitKey()

cv2.destroyAllWindows
# Out:
# <PIL.Image.Image image mode=L size=600x422>
# <function destroyAllWindows>

# %%
type(img2)
# Out:
# numpy.ndarray

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
img1.shape #Colorful #Third one indicates RGB
# Out:
# (422, 600, 3)

# %%
img2.shape #gray
# Out:
# (422, 600)

# %%
print(f"Height of my Image is {img1.shape[0]}")
print(f"Width of my Image is {img1.shape[1]}")
# Out:
# Height of my Image is 422
# Width of my Image is 600
